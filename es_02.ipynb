# %%
# importo le librerie
import pandas as pd

# %%
# importo il csv
df = pd.read_csv("datasets/avocado.csv")

# %%
# preparo il il dataframe selezionando solo la regione "Albany" e settando la data come indice
df['Date'] = pd.to_datetime(df['Date'])
albany_df = df[df['region']=='Albany']
albany_df.set_index("Date", inplace=True)

# %%
# plot della colonna 'AveragePrice'
albany_df['AveragePrice'].plot()

# %%
# considero 25 record consecutivi e ne faccio la media 
# rolling non sovrascrive il dataframe
albany_df["AveragePrice"].rolling(25).mean().plot()

# %%
# se guardo l'indice vedo che non sono in ordine. ecco speigato il grafico precedente
albany_df.index
# Out:
# DatetimeIndex(['2015-12-27', '2015-12-20', '2015-12-13', '2015-12-06',
#                '2015-11-29', '2015-11-22', '2015-11-15', '2015-11-08',
#                '2015-11-01', '2015-10-25',
#                ...
#                '2018-03-11', '2018-03-04', '2018-02-25', '2018-02-18',
#                '2018-02-11', '2018-02-04', '2018-01-28', '2018-01-21',
#                '2018-01-14', '2018-01-07'],
#               dtype='datetime64[ns]', name='Date', length=338, freq=None)

# %%
# riordino il dataframe secondo l'indice
albany_df.sort_index(inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
albany_df["AveragePrice"].rolling(25).mean().plot()

# %%
albany_df['price25ma'] = albany_df["AveragePrice"].rolling(25).mean()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# come mi aspetto le prime 25 righe saranno vuote
# osservo che sono coppie di righe (conventional/organic)
albany_df.head(26)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225    4770  \
# Date
# 2015-01-04          51          1.22      40873.28  2819.50  28287.42   49.90
# 2015-01-04          51          1.79       1373.95    57.42    153.88    0.00
# 2015-01-11          50          1.24      41195.08  1002.85  31640.34  127.12
# 2015-01-11          50          1.77       1182.56    39.00    305.12    0.00
# 2015-01-18          49          1.17      44511.28   914.14  31540.32  135.77
# 2015-01-18          49          1.93       1118.47     8.02    178.78    0.00
# 2015-01-25          48          1.06      45147.50   941.38  33196.16  164.14
# 2015-01-25          48          1.89       1115.89    14.87    148.72    0.00
# 2015-02-01          47          0.99      70873.60  1353.90  60017.20  179.32
# 2015-02-01          47          1.83       1228.51    33.12     99.36    0.00
# 2015-02-08          46          0.99      51253.97  1357.37  39111.81  163.25
# ...

# %%
# scarto le righe con NaN
# anche in questo caso dropna non sovrascrive il dataframe
albany_df.dropna().head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225   4770  \
# Date
# 2015-03-29          39          1.93       1082.44    24.75    173.26   0.00
# 2015-03-29          39          1.02      67799.08  1402.28  58623.22  89.50
# 2015-04-05          38          1.16      47362.13   961.77  35577.66  93.76
# 2015-04-05          38          1.93       1526.10    15.75    202.52   0.00
# 2015-04-12          37          1.76       1634.59    51.75     93.38   0.00
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-03-29      884.43      884.43        0.00         0.00       organic
# 2015-03-29     7684.08     7208.49      475.59         0.00  conventional
# 2015-04-05    10728.94     9869.16      755.61       104.17  conventional
# 2015-04-05     1307.83     1307.83        0.00         0.00       organic
# 2015-04-12     1489.46     1489.46        0.00         0.00       organic
#
#             year  region  price25ma
# Date
# ...

# %%
# con la funzione copy non ho il warning di prima
albany_df = df.copy()[df['region'] == 'Albany']
albany_df.set_index('Date', inplace = True)
albany_df.sort_index(inplace =  True)
albany_df['price25ma'] = albany_df["AveragePrice"].rolling(25).mean()

# %%
df.values
# Out:
# array([[0, Timestamp('2015-12-27 00:00:00'), 1.33, ..., 'conventional',
#         2015, 'Albany'],
#        [1, Timestamp('2015-12-20 00:00:00'), 1.35, ..., 'conventional',
#         2015, 'Albany'],
#        [2, Timestamp('2015-12-13 00:00:00'), 0.93, ..., 'conventional',
#         2015, 'Albany'],
#        ...,
#        [9, Timestamp('2018-01-21 00:00:00'), 1.87, ..., 'organic', 2018,
#         'WestTexNewMexico'],
#        [10, Timestamp('2018-01-14 00:00:00'), 1.93, ..., 'organic', 2018,
#         'WestTexNewMexico'],
#        [11, Timestamp('2018-01-07 00:00:00'), 1.62, ..., 'organic', 2018,
#         'WestTexNewMexico']], dtype=object)

# %%
df['region'].values
# Out:
# array(['Albany', 'Albany', 'Albany', ..., 'WestTexNewMexico',
#        'WestTexNewMexico', 'WestTexNewMexico'], dtype=object)

# %%
df['region'].values.tolist()
# Out:
# ['Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
# ...

# %%
set(df['region'].values.tolist())
# Out:
# {'Albany',
#  'Atlanta',
#  'BaltimoreWashington',
#  'Boise',
#  'Boston',
#  'BuffaloRochester',
#  'California',
#  'Charlotte',
#  'Chicago',
#  'CincinnatiDayton',
#  'Columbus',
#  'DallasFtWorth',
#  'Denver',
#  'Detroit',
#  'GrandRapids',
#  'GreatLakes',
#  'HarrisburgScranton',
#  'HartfordSpringfield',
#  'Houston',
#  'Indianapolis',
#  'Jacksonville',
#  'LasVegas',
#  'LosAngeles',
#  'Louisville',
#  'MiamiFtLauderdale',
#  'Midsouth',
#  'Nashville',
#  'NewOrleansMobile',
#  'NewYork',
#  'Northeast',
#  'NorthernNewEngland',
#  'Orlando',
#  'Philadelphia',
#  'PhoenixTucson',
#  'Pittsburgh',
#  'Plains',
#  'Portland',
#  'RaleighGreensboro',
#  'RichmondNorfolk',
#  'Roanoke',
#  'Sacramento',
#  'SanDiego',
#  'SanFrancisco',
#  'Seattle',
#  'SouthCarolina',
#  'SouthCentral',
#  'Southeast',
#  'Spokane',
#  'StLouis',
#  'Syracuse',
#  'Tampa',
#  'TotalUS',
#  'West',
#  'WestTexNewMexico'}

# %%
list(set(df['region'].values.tolist()))
# Out:
# ['CincinnatiDayton',
#  'Spokane',
#  'Syracuse',
#  'GrandRapids',
#  'LasVegas',
#  'LosAngeles',
#  'Philadelphia',
#  'California',
#  'BuffaloRochester',
#  'GreatLakes',
#  'Chicago',
#  'Charlotte',
#  'NewYork',
#  'SouthCarolina',
#  'West',
#  'Denver',
#  'Portland',
#  'NorthernNewEngland',
#  'Indianapolis',
#  'Midsouth',
#  'RaleighGreensboro',
#  'Orlando',
#  'SanFrancisco',
#  'Detroit',
#  'NewOrleansMobile',
#  'Seattle',
#  'BaltimoreWashington',
#  'Sacramento',
#  'Boise',
#  'Atlanta',
#  'MiamiFtLauderdale',
#  'WestTexNewMexico',
#  'Northeast',
#  'Roanoke',
#  'Albany',
#  'Pittsburgh',
#  'Tampa',
#  'HarrisburgScranton',
#  'Nashville',
#  'Southeast',
#  'Boston',
#  'Plains',
#  'SanDiego',
#  'TotalUS',
#  'SouthCentral',
#  'PhoenixTucson',
#  'Jacksonville',
#  'HartfordSpringfield',
#  'DallasFtWorth',
#  'RichmondNorfolk',
#  'Houston',
#  'Louisville',
#  'Columbus',
#  'StLouis']

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
# questo codice proseguendo col ciclo diventa lentissimo
graph_df = pd.DataFrame()

for region in df['region'].unique()[:16]:
    print(region)
    region_df = df.copy()[df['region'] == region]
    region_df.set_index('Date', inplace = True)
    region_df.sort_index(inplace =  True)
    region_df[f'{region}_price25ma'] = region_df["AveragePrice"].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma']]
        
    else:
        graph_df = graph_df.join(region_df[f'{region}_price25ma'])
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes

# %%
graph_df.head(5)
# Out:
#             Albany_price25ma  Atlanta_price25ma  \
# Date
# 2015-01-04               NaN                NaN
# 2015-01-04               NaN                NaN
# 2015-01-04               NaN                NaN
# 2015-01-04               NaN                NaN
# 2015-01-04               NaN                NaN
#
#             BaltimoreWashington_price25ma  Boise_price25ma  Boston_price25ma  \
# Date
# 2015-01-04                            NaN              NaN               NaN
# 2015-01-04                            NaN              NaN               NaN
# 2015-01-04                            NaN              NaN               NaN
# 2015-01-04                            NaN              NaN               NaN
# 2015-01-04                            NaN              NaN               NaN
#
#             BuffaloRochester_price25ma  California_price25ma  \
# Date
# 2015-01-04                         NaN                   NaN
# 2015-01-04                         NaN                   NaN
# ...

# %%
df.tail(5)
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7 2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
graph_df.tail()
# Out:
#             Albany_price25ma  Atlanta_price25ma  \
# Date
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
#
#             BaltimoreWashington_price25ma  Boise_price25ma  Boston_price25ma  \
# Date
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
#
#             BuffaloRochester_price25ma  California_price25ma  \
# Date
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
# ...

# %%
import pandas as pd

df = pd.read_csv("datasets/avocado.csv")
df = df.copy()[df['type'] == 'organic']
df['Date'] == pd.to_datetime(df['Date'])
df.sort_values(by = 'Date', ascending = True, inplace = True)

# %%
df.head()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume       4046  \
# 9489           51  2015-01-04          1.24     142349.77  107490.73
# 10269          51  2015-01-04          1.50       6329.83    3730.80
# 10893          51  2015-01-04          1.12      17296.85   14569.66
# 9437           51  2015-01-04          1.73        379.82       0.00
# 11621          51  2015-01-04          1.30       5782.70     723.29
#
#            4225  4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 9489   25711.96  2.93     9144.15     9144.15        0.00          0.0
# 10269   2141.91  0.00      457.12      426.67       30.45          0.0
# 10893   1868.59  0.00      858.60      830.00       28.60          0.0
# 9437      59.82  0.00      320.00      320.00        0.00          0.0
# 11621   4221.15  0.00      838.26      223.33      614.93          0.0
#
#           type  year            region
# 9489   organic  2015        California
# 10269  organic  2015          LasVegas
# ...

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique():
    print(region)
    region_df = df.copy()[df['region'] == region]
    region_df.set_index('Date', inplace = True)
    region_df.sort_index(inplace =  True)
    region_df[f'{region}_price25ma'] = region_df["AveragePrice"].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma']]
        
    else:
        graph_df = graph_df.join(region_df[f'{region}_price25ma'])
# Out:
# California
# LasVegas
# PhoenixTucson
# BuffaloRochester
# Spokane
# LosAngeles
# Philadelphia
# Boston
# StLouis
# Louisville
# Orlando
# Southeast
# Boise
# MiamiFtLauderdale
# NorthernNewEngland
# BaltimoreWashington
# Midsouth
# Tampa
# West
# Northeast
# Atlanta
# Nashville
# TotalUS
# Syracuse
# WestTexNewMexico
# Jacksonville
# Charlotte
# Sacramento
# GrandRapids
# Roanoke
# Denver
# SanDiego
# GreatLakes
# RichmondNorfolk
# DallasFtWorth
# SanFrancisco
# HarrisburgScranton
# Pittsburgh
# RaleighGreensboro
# Seattle
# HartfordSpringfield
# Portland
# CincinnatiDayton
# SouthCarolina
# Houston
# Chicago
# Plains
# Indianapolis
# SouthCentral
# Columbus
# Albany
# Detroit
# NewOrleansMobile
# NewYork

# %%
graph_df.tail()
# Out:
#             California_price25ma  LasVegas_price25ma  PhoenixTucson_price25ma  \
# Date
# 2018-02-25                1.9128              1.9120                   1.7468
# 2018-03-04                1.8876              1.8748                   1.7404
# 2018-03-11                1.8636              1.8440                   1.7324
# 2018-03-18                1.8516              1.8204                   1.7216
# 2018-03-25                1.8364              1.7968                   1.7104
#
#             BuffaloRochester_price25ma  Spokane_price25ma  \
# Date
# 2018-02-25                      1.2912             2.1544
# 2018-03-04                      1.2744             2.1040
# 2018-03-11                      1.2652             2.0552
# 2018-03-18                      1.2560             2.0012
# 2018-03-25                      1.2416             1.9496
#
#             LosAngeles_price25ma  Philadelphia_price25ma  Boston_price25ma  \
# Date
# ...

# %%
graph_df['LasVegas_price25ma'].plot()
graph_df['WestTexNewMexico_price25ma'].plot()

#graph_df.plot()

# %%
graph_df.corr()
# Out:
#                                California_price25ma  LasVegas_price25ma  \
# California_price25ma                       1.000000            0.757597
# LasVegas_price25ma                         0.757597            1.000000
# PhoenixTucson_price25ma                    0.725067            0.883830
# BuffaloRochester_price25ma                -0.234015           -0.483965
# Spokane_price25ma                          0.881914            0.752356
# LosAngeles_price25ma                       0.934726            0.671394
# Philadelphia_price25ma                    -0.028112           -0.000153
# Boston_price25ma                           0.299147           -0.251278
# StLouis_price25ma                          0.653674            0.422288
# Louisville_price25ma                       0.426764            0.498429
# Orlando_price25ma                          0.609638            0.351080
# Southeast_price25ma                        0.601306            0.494143
# ...

# %%
import matplotlib.pyplot as plt
plt.matshow(graph_df.corr())
plt.xticks(range(len(graph_df.columns)), graph_df.columns)
plt.yticks(range(len(graph_df.columns)), graph_df.columns)
plt.colorbar()
plt.show()

# %%
graph_df.plot(figsize=(12,9), legend=False)
